# %% [markdown]
# # Satandar Customer Transaction Predicition
#
# ## Data Exploration and Analysis

# %%
# Import Libraries

import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
#read CSV files

raw_train = pd.read_csv("train.csv")
raw_test = pd.read_csv("test.csv")

# %%
raw_train.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
print("Training Data Size: {}, Testing Data Size: {}".format(len(raw_train), len(raw_test)))
# Out:
# Training Data Size: 200000, Testing Data Size: 200000

# %% [markdown]
# 1.1 Check for missing values

# %%
print("Missing in train: {}, Missing in test: {}".format(raw_train.isna().any().sum(), raw_test.isna().any().sum()))
# Out:
# Missing in train: 0, Missing in test: 0

# %% [markdown]
# 1.2 Distribution and Correlation

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
g=raw_train[:20]

# %%
var_cols = [columns for columns in raw_train.columns if columns.startswith("var_")]

nrows = 50
fig, axs = plt.subplots(nrows=50, ncols=4, figsize=(24, nrows * 5))

for idx, val in enumerate(var_cols, 1):
    plt.subplot(50, 4, idx)
    sns.kdeplot(raw_train[val], shade=True)
    sns.kdeplot(raw_test[val], shade=True)
    
    plt.tick_params(axis='x', which='major', labelsize=8)
    plt.tick_params(axis='y', which='major', labelsize=8)
    
    plt.legend(loc='upper right')
    plt.title('Distribution of {} in Training and Test Set'.format(feature))
    
plt.show()

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
train_loader = torch.utils.data.DataLoader(datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])), batch_size=args.batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args.test_batch_size, shuffle=True, **kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-93b1ea4d104b> in <module>
# ----> 1 train_loader = torch.utils.data.DataLoader( datasets.MNIST('../data', train=True, download=True,
#       2                    transform=transforms.Compose([
#       3                        transforms.ToTensor(),
#       4                        transforms.Normalize((0.1307,), (0.3081,))
#       5                    ])), batch_size=args.batch_size, shuffle=True, **kwargs)
#
# NameError: name 'datasets' is not defined
