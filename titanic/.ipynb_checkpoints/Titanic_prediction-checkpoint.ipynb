# %%
#Import Libraries
from matplotlib import pyplot as plt
import sklearn
import pandas as pd
import numpy as np
import xgboost as xgb

# %%
#Import Datasets

train_dataset = pd.read_csv("dataset/train.csv")
test_dataset = pd.read_csv("dataset/test.csv")

# %%
def preprocess(titanic_df):
    titanic_df['Sex'].replace(to_replace=dict(female=0, male=1), inplace=True)

# %%
test = train_dataset
y_train = test["Survived"]
test=test.drop(["Survived"], axis=1)

# %%
combined = test.append(test_dataset)

# %%
combined.reset_index().drop(["index"], axis=1)
combined = combined.drop(["PassengerId"], axis=1)

# %%
#process Sex
combined['Sex'].replace(to_replace=dict(female=0, male=1), inplace=True)

# %%
#process_Pclass():
combined.Pclass.isnull().any()
one_hot_pclass= pd.DataFrame(pd.get_dummies(combined["Pclass"]))
combined=pd.concat([combined, one_hot_pclass], axis=1)

# %%
#passenger names

combined=combined.reset_index().drop(["index"], axis=1)

# %%
combined['title'] = combined['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())
combined.title.unique
# Out:
# <bound method Series.unique of 0           Mr
# 1          Mrs
# 2         Miss
# 3          Mrs
# 4           Mr
# 5           Mr
# 6           Mr
# 7       Master
# 8          Mrs
# 9          Mrs
# 10        Miss
# 11        Miss
# 12          Mr
# 13          Mr
# 14        Miss
# 15         Mrs
# 16      Master
# 17          Mr
# 18         Mrs
# 19         Mrs
# 20          Mr
# 21          Mr
# 22        Miss
# 23          Mr
# 24        Miss
# 25         Mrs
# 26          Mr
# 27          Mr
# 28        Miss
# 29          Mr
#          ...
# 1279        Mr
# 1280    Master
# 1281        Mr
# 1282       Mrs
# 1283    Master
# 1284        Mr
# 1285        Mr
# 1286       Mrs
# 1287        Mr
# 1288       Mrs
# 1289        Mr
# 1290        Mr
# 1291      Miss
# 1292        Mr
# 1293      Miss
# 1294        Mr
# 1295        Mr
# 1296        Mr
# 1297        Mr
# 1298        Mr
# 1299      Miss
# 1300      Miss
# 1301      Miss
# 1302       Mrs
# 1303      Miss
# 1304        Mr
# 1305      Dona
# 1306        Mr
# 1307        Mr
# 1308    Master
# Name: title, Length: 1309, dtype: object>

# %%
combined
# Out:
#       Pclass                                               Name  Sex   Age  \
# 0          3                            Braund, Mr. Owen Harris    1  22.0
# 1          1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2          3                             Heikkinen, Miss. Laina    0  26.0
# 3          1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4          3                           Allen, Mr. William Henry    1  35.0
# 5          3                                   Moran, Mr. James    1   NaN
# 6          1                            McCarthy, Mr. Timothy J    1  54.0
# 7          3                     Palsson, Master. Gosta Leonard    1   2.0
# 8          3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    0  27.0
# 9          2                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0
# 10         3                    Sandstrom, Miss. Marguerite Rut    0   4.0
# 11         1                           Bonnell, Miss. Elizabeth    0  58.0
# 12         3                     Saundercock, Mr. William Henry    1  20.0
# 13         3                        Andersson, Mr. Anders Johan    1  39.0
# 14         3               Vestrom, Miss. Hulda Amanda Adolfina    0  14.0
# 15         2                   Hewlett, Mrs. (Mary D Kingcome)     0  55.0
# 16         3                               Rice, Master. Eugene    1   2.0
# 0     1      Mr
# 1     0     Mrs
# 2     1    Miss
# 3     0     Mrs
# 4     1      Mr
# 5     1      Mr
# 6     0      Mr
# 7     1  Master
# 8     1     Mrs
# 9     0     Mrs
# 10    1    Miss
# 11    0    Miss
# 12    1      Mr
# 13    1      Mr
# 14    1    Miss
# 15    0     Mrs
# 16    1  Master
# 17    0      Mr
# 18    1     Mrs
# 19    1     Mrs
# 20    0      Mr
# 21    0      Mr
# 22    1    Miss
# 23    0      Mr
# 24    1    Miss
# 25    1     Mrs
# 26    1      Mr
# 27    0      Mr
# 28    1    Miss
# 29    1      Mr
# ...  ..     ...
# 1279  1      Mr
# 1280  1  Master
# 1281  0      Mr
# 1282  0     Mrs
# 1283  1  Master
# 1284  0      Mr
# 1285  1      Mr
# 1286  0     Mrs
# 1287  1      Mr
# 1288  0     Mrs
# 1289  1      Mr
# 1290  1      Mr
# 1291  0    Miss
# 1292  0      Mr
# 1293  0    Miss
# 1294  0      Mr
# 1295  0      Mr
# 1296  0      Mr
# 1297  0      Mr
# 1298  0      Mr
# 1299  1    Miss
# 1300  1    Miss
# 1301  1    Miss
# 1302  0     Mrs
# 1303  1    Miss
# 1304  1      Mr
# 1305  0    Dona
# 1306  1      Mr
# 1307  1      Mr
# 1308  1  Master
#
# [1309 rows x 14 columns]

# %%
# Passenger classes

#process_Embarked

Title_Dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir" : "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "the Countess":"Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr" : "Mr",
    "Mrs" : "Mrs",
    "Miss" : "Miss",
    "Master" : "Master",
    "Lady" : "Royalty"
}

combined['title'] = combined.title.map(Title_Dictionary)
one_hot_title = pd.DataFrame(pd.get_dummies(combined["title"]))
combined = pd.concat([combined, one_hot_title], axis=1)

# %%
combined
# Out:
#       Pclass                                               Name  Sex   Age  \
# 0          3                            Braund, Mr. Owen Harris    1  22.0
# 1          1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2          3                             Heikkinen, Miss. Laina    0  26.0
# 3          1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4          3                           Allen, Mr. William Henry    1  35.0
# 5          3                                   Moran, Mr. James    1   NaN
# 6          1                            McCarthy, Mr. Timothy J    1  54.0
# 7          3                     Palsson, Master. Gosta Leonard    1   2.0
# 8          3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    0  27.0
# 9          2                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0
# 10         3                    Sandstrom, Miss. Marguerite Rut    0   4.0
# 11         1                           Bonnell, Miss. Elizabeth    0  58.0
# 12         3                     Saundercock, Mr. William Henry    1  20.0
# 13         3                        Andersson, Mr. Anders Johan    1  39.0
# 14         3               Vestrom, Miss. Hulda Amanda Adolfina    0  14.0
# 15         2                   Hewlett, Mrs. (Mary D Kingcome)     0  55.0
# 16         3                               Rice, Master. Eugene    1   2.0
# 17         2                       Williams, Mr. Charles Eugene    1   NaN
# 18         3  Vander Planke, Mrs. Julius (Emelia Maria Vande...    0  31.0
# 19         3                            Masselmani, Mrs. Fatima    0   NaN
# 20         2                               Fynney, Mr. Joseph J    1  35.0
# 21         2                              Beesley, Mr. Lawrence    1  34.0
# 22         3                        McGowan, Miss. Anna "Annie"    0  15.0
# 23         1                       Sloper, Mr. William Thompson    1  28.0
# 24         3                      Palsson, Miss. Torborg Danira    0   8.0
# 25         3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 12    1      Mr       0     0   1    0        0        0
# 13    1      Mr       0     0   1    0        0        0
# 14    1    Miss       0     1   0    0        0        0
# 15    0     Mrs       0     0   0    1        0        0
# 16    1  Master       1     0   0    0        0        0
# 17    0      Mr       0     0   1    0        0        0
# 18    1     Mrs       0     0   0    1        0        0
# 19    1     Mrs       0     0   0    1        0        0
# 20    0      Mr       0     0   1    0        0        0
# 21    0      Mr       0     0   1    0        0        0
# 22    1    Miss       0     1   0    0        0        0
# 23    0      Mr       0     0   1    0        0        0
# 24    1    Miss       0     1   0    0        0        0
# 25    1     Mrs       0     0   0    1        0        0
# 26    1      Mr       0     0   1    0        0        0
# 27    0      Mr       0     0   1    0        0        0
# 28    1    Miss       0     1   0    0        0        0
# 29    1      Mr       0     0   1    0        0        0
# ...  ..     ...     ...   ...  ..  ...      ...      ...
# 1279  1      Mr       0     0   1    0        0        0
# 1280  1  Master       1     0   0    0        0        0
# 1281  0      Mr       0     0   1    0        0        0
# 1282  0     Mrs       0     0   0    1        0        0
# 1283  1  Master       1     0   0    0        0        0
# 1284  0      Mr       0     0   1    0        0        0
# 1285  1      Mr       0     0   1    0        0        0
# 1286  0     Mrs       0     0   0    1        0        0
# 1287  1      Mr       0     0   1    0        0        0
# 1288  0     Mrs       0     0   0    1        0        0
# 1289  1      Mr       0     0   1    0        0        0
# 1290  1      Mr       0     0   1    0        0        0
# 1291  0    Miss       0     1   0    0        0        0
# 1292  0      Mr       0     0   1    0        0        0
# 1293  0    Miss       0     1   0    0        0        0
# 1294  0      Mr       0     0   1    0        0        0
# 1295  0      Mr       0     0   1    0        0        0
# 1296  0      Mr       0     0   1    0        0        0
# 1297  0      Mr       0     0   1    0        0        0
# 1298  0      Mr       0     0   1    0        0        0
# 1299  1    Miss       0     1   0    0        0        0
# 1300  1    Miss       0     1   0    0        0        0
# 1301  1    Miss       0     1   0    0        0        0
# 1302  0     Mrs       0     0   0    1        0        0
# 1303  1    Miss       0     1   0    0        0        0
# 1304  1      Mr       0     0   1    0        0        0
# 1305  0     NaN       0     0   0    0        0        0
# 1306  1      Mr       0     0   1    0        0        0
# 1307  1      Mr       0     0   1    0        0        0
# 1308  1  Master       1     0   0    0        0        0
#
# [1309 rows x 20 columns]

# %%
#process age

grouped_train = combined.iloc[:891].groupby(['Sex','Pclass','title'])
grouped_median_train = grouped_train.median()
grouped_median_train = grouped_median_train.reset_index()[['Sex', 'Pclass', 'title', 'Age']]

# %%
def fill_age(row):
    condition = (
        (grouped_median_train['Sex'] == row['Sex']) & 
        (grouped_median_train['title'] == row['title']) & 
        (grouped_median_train['Pclass'] == row['Pclass'])
    ) 
    return grouped_median_train[condition]['Age'].values[0]


def process_age():
    global combined
    # a function that fills the missing values of the Age variable
    combined['Age'] = combined.apply(lambda row: fill_age(row) if np.isnan(row['Age']) else row['Age'], axis=1)
    return combined

# %%
combined = process_age()

# %%
# process embarked 

combined.Embarked.value_counts()
combined.Embarked.fillna('S', inplace=True)

one_hot_embarked = pd.get_dummies(combined["Embarked"], prefix="Embarked_")
combined = pd.concat([combined, one_hot_embarked], axis=1)

# %%
combined
# Out:
#       Pclass                                               Name  Sex   Age  \
# 0          3                            Braund, Mr. Owen Harris    1  22.0
# 1          1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 1300     ...         Miss       0     1  0    0        0        0
# 1301     ...         Miss       0     1  0    0        0        0
# 1302     ...          Mrs       0     0  0    1        0        0
# 1303     ...         Miss       0     1  0    0        0        0
# 1304     ...           Mr       0     0  1    0        0        0
# 1305     ...          NaN       0     0  0    0        0        0
# 1306     ...           Mr       0     0  1    0        0        0
# 1307     ...           Mr       0     0  1    0        0        0
# 1308     ...       Master       1     0  0    0        0        0
#
#       Embarked__C  Embarked__Q  Embarked__S
# 0               0            0            1
# 1               1            0            0
# 2               0            0            1
# 3               0            0            1
# 4               0            0            1
# 5               0            1            0
# 6               0            0            1
# 7               0            0            1
# 8               0            0            1
# 9               1            0            0
# 10              0            0            1
# 11              0            0            1
# 12              0            0            1
# 13              0            0            1
# 14              0            0            1
# 15              0            0            1
# 16              0            1            0
# 17              0            0            1
# 18              0            0            1
# 19              1            0            0
# 20              0            0            1
# 21              0            0            1
# 22              0            1            0
# 23              0            0            1
# 24              0            0            1
# 25              0            0            1
# 26              1            0            0
# 27              0            0            1
# 28              0            1            0
# 29              0            0            1
# ...           ...          ...          ...
# 1279            0            1            0
# 1280            0            0            1
# 1281            0            0            1
# 1282            0            0            1
# 1283            0            0            1
# 1284            0            0            1
# 1285            0            0            1
# 1286            0            0            1
# 1287            0            1            0
# 1288            1            0            0
# 1289            0            0            1
# 1290            0            1            0
# 1291            0            0            1
# 1292            0            0            1
# 1293            1            0            0
# 1294            0            0            1
# 1295            1            0            0
# 1296            1            0            0
# 1297            0            0            1
# 1298            1            0            0
# 1299            0            1            0
# 1300            0            0            1
# 1301            0            1            0
# 1302            0            1            0
# 1303            0            0            1
# 1304            0            0            1
# 1305            1            0            0
# 1306            0            0            1
# 1307            0            0            1
# 1308            1            0            0
#
# [1309 rows x 23 columns]

# %%
def process_family():
    
    global combined
    # introducing a new feature : the size of families (including the passenger)
    combined['FamilySize'] = combined['Parch'] + combined['SibSp'] + 1
    
    # introducing other features based on the family size
    combined['Singleton'] = combined['FamilySize'].map(lambda s: 1 if s == 1 else 0)
    combined['SmallFamily'] = combined['FamilySize'].map(lambda s: 1 if 2 <= s <= 4 else 0)
    combined['LargeFamily'] = combined['FamilySize'].map(lambda s: 1 if 5 <= s else 0)
    
    return combined

# %%
# Process SibSp and Parch

combined = process_family()

# %%
combined.Age.value_counts()

combined["children"] = combined["Age"].map(lambda s: 1 if s < 18 else 0)
combined["young_adults"] = combined["Age"].map(lambda s: 1 if s >= 18 and s < 36 else 0)
combined["middle_age"] = combined["Age"].map(lambda s: 1 if s >= 36 and s < 56 else 0)
combined["old"] = combined["Age"].map(lambda s: 1 if s >= 56 else 0)

# %%
# process fare

def process_fares():
    global combined
    # there's one missing fare value - replacing it with the mean.
    combined.Fare.fillna(combined.iloc[:891].Fare.mean(), inplace=True)
    return combined

# %%
combined = process_fares()

# %%
# process ticket

def process_ticket():
    
    global combined
    
    # a function that extracts each prefix of the ticket, returns 'XXX' if no prefix (i.e the ticket is a digit)
    def cleanTicket(ticket):
        ticket = ticket.replace('.','')
        ticket = ticket.replace('/','')
        ticket = ticket.split()
        ticket = map(lambda t : t.strip(), ticket)
        ticket = list(filter(lambda t : not t.isdigit(), ticket))
        if len(ticket) > 0:
            return ticket[0]
        else: 
            return 'XXX'
    

    # Extracting dummy variables from tickets:

    combined['Ticket'] = combined['Ticket'].map(cleanTicket)
    tickets_dummies = pd.get_dummies(combined['Ticket'], prefix='Ticket')
    combined = pd.concat([combined, tickets_dummies], axis=1)
    combined.drop('Ticket', inplace=True, axis=1)

    status('Ticket')
    return combined

combined = process_ticket()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-a2ff5dd9ebfe> in <module>()
#      28     return combined
#      29
# ---> 30 combined = process_ticket()
#
# <ipython-input-44-a2ff5dd9ebfe> in process_ticket()
#      20     # Extracting dummy variables from tickets:
#      21
# ---> 22     combined['Ticket'] = combined['Ticket'].map(cleanTicket)
#      23     tickets_dummies = pd.get_dummies(combined['Ticket'], prefix='Ticket')
#      24     combined = pd.concat([combined, tickets_dummies], axis=1)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'

# %%
def process_cabin():
    global combined    
    # replacing missing cabins with U (for Uknown)
    combined.Cabin.fillna('U', inplace=True)
    
    # mapping each Cabin value with the cabin letter
    combined['Cabin'] = combined['Cabin'].map(lambda c: c[0])
    
    # dummy encoding ...
    cabin_dummies = pd.get_dummies(combined['Cabin'], prefix='Cabin')    
    combined = pd.concat([combined, cabin_dummies], axis=1)

    combined.drop('Cabin', axis=1, inplace=True)
    return combined

# %%
#process cabin
combined = process_cabin()

# %%
combined.columns
# Out:
# Index([        'Pclass',           'Name',            'Sex',            'Age',
#                 'SibSp',          'Parch',           'Fare',       'Embarked',
#                       1,                2,                3,          'title',
#                'Master',           'Miss',             'Mr',            'Mrs',
#               'Officer',        'Royalty',    'Embarked__C',    'Embarked__Q',
#           'Embarked__S',     'FamilySize',      'Singleton',    'SmallFamily',
#           'LargeFamily',       'children',   'young_adults',     'middle_age',
#                   'old',       'Ticket_A',      'Ticket_A4',      'Ticket_A5',
#            'Ticket_AQ3',     'Ticket_AQ4',      'Ticket_AS',       'Ticket_C',
#             'Ticket_CA', 'Ticket_CASOTON',      'Ticket_FC',     'Ticket_FCC',
#             'Ticket_Fa',    'Ticket_LINE',      'Ticket_LP',      'Ticket_PC',
#             'Ticket_PP',     'Ticket_PPP',      'Ticket_SC',    'Ticket_SCA3',
#           'Ticket_SCA4',    'Ticket_SCAH',    'Ticket_SCOW', 'Ticket_SCPARIS',
#        'Ticket_SCParis',     'Ticket_SOC',     'Ticket_SOP',    'Ticket_SOPP',
#        'Ticket_SOTONO2', 'Ticket_SOTONOQ',      'Ticket_SP',   'Ticket_STONO',
#         'Ticket_STONO2',  'Ticket_STONOQ',    'Ticket_SWPP',      'Ticket_WC',
#            'Ticket_WEP',     'Ticket_XXX',        'Cabin_A',        'Cabin_B',
#               'Cabin_C',        'Cabin_D',        'Cabin_E',        'Cabin_F',
#               'Cabin_G',        'Cabin_T',        'Cabin_U'],
#       dtype='object')
